# %% [markdown]
# ## Web Scraping

# %%
from selenium import webdriver as web

import time, os
# from selenium.webdriver.common.keys import Keys

from bs4 import BeautifulSoup
import requests
#  webdriver is what is driving these actions.
# It's what'is links up with the browser.
# It's what's able to perform the action

# %%
PATH='/Applications/chromedriver'
os.environ["webdriver.chrome.driver"] = PATH

driver=web.Chrome(PATH)

# The web browser i want to use is chrome and the web driver for this browser is locted at PATH.

# %%
driver.get('https://www.jarir.com')

# %% [markdown]
# Now we parse this with `BeautifulSoup` and the bookstore information appears!

# %%
driver.find_element_by_xpath('/html/body/div[3]/div/div[1]/div/div/div[3]/ul/div/div/div[5]/div/li/a/div/img').click()

# %%
#  This line will view the laptops page.

driver.find_element_by_xpath('//*[@id="amshopby-page-container"]/div[7]/ul/li[1]/a/div/img').click()

# %% [markdown]
# Now we want to collect all the link of the product that show in page.

# %%
from selenium.webdriver.common.action_chains import ActionChains

# %%
listOflinks=[]
 

i=0
while i<2000:
    productInfolist=driver.find_elements_by_class_name('item')
    for p in productInfolist:
        p1=p.find_element_by_tag_name('a')
        p2=p1.get_property('href')
        listOflinks.append(p2)
        i+=1
        try:
            button = driver.find_element_by_xpath("/html/body/div[3]/div/div[1]/div[2]/div[2]/div[2]/div[4]/div[4]")
#             button.click()
            ActionChains(driver).move_to_element(button).click(button).perform()    
        except:
            pass
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# <ipython-input-23-ca18d2645f8b> in <module>
#       6     productInfolist=driver.find_elements_by_class_name('item')
#       7     for p in productInfolist:
# ----> 8         p1=p.find_element_by_tag_name('a')
#       9         p2=p1.get_property('href')
#      10         listOflinks.append(p2)
#
# /opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in find_element_by_tag_name(self, name)
#     303             element = element.find_element_by_tag_name('h1')
#     304         """
# --> 305         return self.find_element(by=By.TAG_NAME, value=name)
#     306
#     307     def find_elements_by_tag_name(self, name):
#
# /opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in find_element(self, by, value)
#     656                 value = '[name="%s"]' % value
#     657
# --> 658         return self._execute(Command.FIND_CHILD_ELEMENT,
#     659                              {"using": by, "value": value})['value']
#     660
#
# /opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# /opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# /opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=94.0.4606.81)

# %%
#  That show the number of all product
len(listOflinks)
# Out:
# 368

# %%
tempj={ 'Company':[],
       'TypeName':[],
       'Inches':[],
       'ScreenResolution':[],
       'Cpu':[],
       'Ram':[],
       'Memory':[],
       'Gpu':[],
       'OpSys':[],
       'Weight':[],
       'Price':[],
}
for link in range(len(listOflinks)):
    driver.get(listOflinks[link])
    english_page = driver.find_element_by_xpath('//*[@id="page-header"]/div[1]/div/ul/li[8]/a/div[2]')
    english_page.click()
    Company=driver.find_element_by_xpath('//*[@id="card-specifications"]/div/table/tbody/tr[9]/td').get_attribute('textContent').strip()
    TypeName=driver.find_element_by_xpath('//*[@id="card-specifications"]/div/table/tbody/tr[8]/td').get_attribute('textContent').strip()
    Inches=driver.find_element_by_xpath('//*[@id="card-specifications"]/div/table/tbody/tr[6]/td').get_attribute('textContent').strip().replace("\"", "")
    ScreenResolution=driver.find_element_by_xpath('//*[@id="card-specifications"]/div/table/tbody/tr[19]/td').get_attribute('textContent').strip()
    Cpu=driver.find_element_by_xpath('//*[@id="card-specifications"]/div/table/tbody/tr[4]/td').get_attribute('textContent').strip()
    Ram=driver.find_element_by_xpath('//*[@id="card-specifications"]/div/table/tbody/tr[15]/td').get_attribute('textContent').strip()
    Memory=driver.find_element_by_xpath('//*[@id="card-specifications"]/div/table/tbody/tr[14]/td').get_attribute('textContent').strip()
    Gpu=driver.find_element_by_xpath('//*[@id="card-specifications"]/div/table/tbody/tr[7]/td').get_attribute('textContent').strip()
    OpSys=driver.find_element_by_xpath('//*[@id="card-specifications"]/div/table/tbody/tr[7]/td').get_attribute('textContent').strip()
    Price=driver.find_element_by_class_name('price').get_attribute('textContent').strip().replace("SR", "")
    Company1=Company[:7]
    Company2=Company[:6]
    Company3=Company[:4]
    Company4=Company[:8]
    if Company1=='(Apple)'or Company2=='(Asus)':
        Weight=driver.find_element_by_xpath('//*[@id="card-specifications"]/div/table/tbody/tr[24]/td').get_attribute('textContent').strip()
    elif Company4 == '(Huawei)':
        Weight=driver.find_element_by_xpath('//*[@id="card-specifications"]/div/table/tbody/tr[25]/th').get_attribute('textContent').strip()
    elif Company3 == '(HP)':
        Weight=driver.find_element_by_xpath('//*[@id="card-specifications"]/div/table/tbody/tr[22]/td').get_attribute('textContent').strip()
    elif Company2=='(Dell)':
        Weight=driver.find_element_by_xpath('//*[@id="card-specifications"]/div/table/tbody/tr[25]/th').get_attribute('textContent').strip()

    else:
        Weight=None
    tempj['Company'].append(Company)
    tempj['TypeName'].append(TypeName)
    tempj['Inches'].append(Inches)
    tempj['ScreenResolution'].append(ScreenResolution)
    tempj['Cpu'].append(Gpu)
    tempj['Ram'].append(Ram)
    tempj['Memory'].append(Memory)
    tempj['Gpu'].append(Memory)
    tempj['OpSys'].append(OpSys)
    tempj['Weight'].append(Weight)
    tempj['Price'].append(Price)
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# <ipython-input-25-e05a6c88b1a6> in <module>
#      15     english_page = driver.find_element_by_xpath('//*[@id="page-header"]/div[1]/div/ul/li[8]/a/div[2]')
#      16     english_page.click()
# ---> 17     Company=driver.find_element_by_xpath('//*[@id="card-specifications"]/div/table/tbody/tr[9]/td').get_attribute('textContent').strip()
#      18     TypeName=driver.find_element_by_xpath('//*[@id="card-specifications"]/div/table/tbody/tr[8]/td').get_attribute('textContent').strip()
#      19     Inches=driver.find_element_by_xpath('//*[@id="card-specifications"]/div/table/tbody/tr[6]/td').get_attribute('textContent').strip().replace("\"", "")
#
# /opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in get_attribute(self, name)
#     137         attributeValue = ''
#     138         if self._w3c:
# --> 139             attributeValue = self.parent.execute_script(
#     140                 "return (%s).apply(null, arguments);" % getAttribute_js,
#     141                 self, name)
#
# /opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute_script(self, script, *args)
#     632             command = Command.EXECUTE_SCRIPT
#     633
# --> 634         return self.execute(command, {
#     635             'script': script,
#     636             'args': converted_args})['value']
#
# /opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# /opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=94.0.4606.81)

# %%
import pandas as pd

# %%
df=pd.DataFrame(tempj)
df
# Out:
#                        Company TypeName Inches  \
# 0          (Apple) MacBook Pro   Laptop   14.2
# 1          (Apple) MacBook Pro   Laptop   16.2
# 2          (Apple) MacBook Pro   Laptop   16.2
# 3          (Apple) MacBook Pro   Laptop   16.2
# 4          (Apple) MacBook Pro   Laptop   14.2
# 5            (Huawei) MateBook   Laptop   13.9
# 6                (Lenovo) YOGA   Laptop     14
# 7   (Microsoft) Surface Laptop   Laptop     15
# 8          (Apple) MacBook Pro   Laptop     16
# 9          (Apple) MacBook Pro   Laptop   13.3
# 10         (Apple) MacBook Pro   Laptop   13.3
# 11           (Huawei) MateBook   Laptop   15.6
# 12           (Huawei) MateBook   Laptop   15.6
# 13         (Apple) MacBook Pro   Laptop   13.3
# 14                  (Dell) XPS   Laptop   13.4
# 15             (Asus) VivoBook   Laptop     14
# 16               (Dell) Vostro   Laptop     14
# 17             (Dell) Inspiron   Laptop   13.3
# 18             (Dell) Inspiron   Laptop   13.3
# 19                  (Dell) XPS   Laptop   13.3
# 20         (Apple) MacBook Pro   Laptop   14.2
# 21         (Apple) MacBook Pro   Laptop   16.2
# 22         (Apple) MacBook Pro   Laptop   16.2
# 23         (Apple) MacBook Pro   Laptop   16.2
# 24         (Apple) MacBook Pro   Laptop   14.2
# 25           (Huawei) MateBook   Laptop   13.9
# 26               (Lenovo) YOGA   Laptop     14
# 27  (Microsoft) Surface Laptop   Laptop     15
# 28         (Apple) MacBook Pro   Laptop     16
# 29         (Apple) MacBook Pro   Laptop   13.3
# 30         (Apple) MacBook Pro   Laptop   13.3
# 31           (Huawei) MateBook   Laptop   15.6
# 32           (Huawei) MateBook   Laptop   15.6
# 33         (Apple) MacBook Pro   Laptop   13.3
# 34                  (Dell) XPS   Laptop   13.4
# 35             (Asus) VivoBook   Laptop     14
# 36               (Dell) Vostro   Laptop     14
# 37             (Dell) Inspiron   Laptop   13.3
# 38             (Dell) Inspiron   Laptop   13.3
# 39                  (Dell) XPS   Laptop   13.3
# 40         (Apple) MacBook Pro   Laptop   14.2
# 41         (Apple) MacBook Pro   Laptop   16.2
# 42         (Apple) MacBook Pro   Laptop   16.2
# 43         (Apple) MacBook Pro   Laptop   16.2
# 44         (Apple) MacBook Pro   Laptop   14.2
# 45           (Huawei) MateBook   Laptop   13.9
# 46               (Lenovo) YOGA   Laptop     14
# 47  (Microsoft) Surface Laptop   Laptop     15
# 48         (Apple) MacBook Pro   Laptop     16
# 49         (Apple) MacBook Pro   Laptop   13.3
# 50         (Apple) MacBook Pro   Laptop   13.3
# 51           (Huawei) MateBook   Laptop   15.6
# 52           (Huawei) MateBook   Laptop   15.6
# 53         (Apple) MacBook Pro   Laptop   13.3
#
#                   ScreenResolution             Cpu  \
# 0                              Yes  MacOS Monterey
# 1                              Yes  MacOS Monterey
# 2                              Yes  MacOS Monterey
# 3                              Yes  MacOS Monterey
# 4                              Yes  MacOS Monterey
# 5                      3000 X 2000      Windows 10
# 6                   HD 720p Webcam      Windows 10
# 7                      2496 x 1664      Windows 10
# 8   Dolby Atmos, Three Microphones  macOS Catalina
# 9            Built-in Mic/Speakers  macOS Catalina
# 10           Built-in Mic/Speakers  macOS Catalina
# 11                HD (1 MP) Webcam      Windows 10
# 12                HD (1 MP) Webcam      Windows 10
# 13           Built-in Mic/Speakers  macOS Catalina
# 14               3840 X 2160 (UHD)      Windows 10
# 15                      VGA Webcam      Windows 10
# 16                   0.9 MP Webcam      Windows 10
# 17                   0.9 MP Webcam      Windows 10
# 18                   0.9 MP Webcam      Windows 10
# 19             Waves MaxxAudio Pro      Windows 10
# 20                             Yes  MacOS Monterey
# 21                             Yes  MacOS Monterey
# 22                             Yes  MacOS Monterey
# 23                             Yes  MacOS Monterey
# 24                             Yes  MacOS Monterey
# 25                     3000 X 2000      Windows 10
# 26                  HD 720p Webcam      Windows 10
# 27                     2496 x 1664      Windows 10
# 28  Dolby Atmos, Three Microphones  macOS Catalina
# 29           Built-in Mic/Speakers  macOS Catalina
# 30           Built-in Mic/Speakers  macOS Catalina
# 31                HD (1 MP) Webcam      Windows 10
# 32                HD (1 MP) Webcam      Windows 10
# 33           Built-in Mic/Speakers  macOS Catalina
# 34               3840 X 2160 (UHD)      Windows 10
# 35                      VGA Webcam      Windows 10
# 36                   0.9 MP Webcam      Windows 10
# 37                   0.9 MP Webcam      Windows 10
# 38                   0.9 MP Webcam      Windows 10
# 39             Waves MaxxAudio Pro      Windows 10
# 40                             Yes  MacOS Monterey
# 41                             Yes  MacOS Monterey
# 42                             Yes  MacOS Monterey
# 43                             Yes  MacOS Monterey
# 44                             Yes  MacOS Monterey
# 45                     3000 X 2000      Windows 10
# 46                  HD 720p Webcam      Windows 10
# 47                     2496 x 1664      Windows 10
# 48  Dolby Atmos, Three Microphones  macOS Catalina
# 49           Built-in Mic/Speakers  macOS Catalina
# 50           Built-in Mic/Speakers  macOS Catalina
# 51                HD (1 MP) Webcam      Windows 10
# 52                HD (1 MP) Webcam      Windows 10
# 53           Built-in Mic/Speakers  macOS Catalina
#
#                                           Ram                    Memory  \
# 0   HDMI/USB-C (Thunderbolt 4)/Headphone Jack           Wi-Fi/Bluetooth
# 1   HDMI/USB-C (Thunderbolt 4)/Headphone Jack           Wi-Fi/Bluetooth
# 2   HDMI/USB-C (Thunderbolt 4)/Headphone Jack           Wi-Fi/Bluetooth
# 3   HDMI/USB-C (Thunderbolt 4)/Headphone Jack           Wi-Fi/Bluetooth
# 4   HDMI/USB-C (Thunderbolt 4)/Headphone Jack           Wi-Fi/Bluetooth
# 5                                   16 GB RAM    1 TB PCIe NVMe M.2 SSD
# 6                                   16 GB RAM    1 TB PCIe NVMe M.2 SSD
# 7                                   16 GB RAM                256 GB SSD
# 8                             Wi-Fi/Bluetooth                 16 GB RAM
# 9                             Wi-Fi/Bluetooth                 16 GB RAM
# 10                            Wi-Fi/Bluetooth                 16 GB RAM
# 11                                   8 GB RAM                256 GB SSD
# 12                                   8 GB RAM                256 GB SSD
# 13                            Wi-Fi/Bluetooth                 16 GB RAM
# 14                                  16 GB RAM    1 TB PCIe NVMe M.2 SSD
# 15                                   4 GB RAM                128 GB SSD
# 16                                   4 GB RAM                  1 TB HDD
# 17                                   8 GB RAM  256 GB PCIe NVMe M.2 SSD
# 18                                   8 GB RAM  512 GB PCIe NVMe M.2 SSD
# 19                            Wi-Fi/Bluetooth                 16 GB RAM
# 20  HDMI/USB-C (Thunderbolt 4)/Headphone Jack           Wi-Fi/Bluetooth
# 21  HDMI/USB-C (Thunderbolt 4)/Headphone Jack           Wi-Fi/Bluetooth
# 22  HDMI/USB-C (Thunderbolt 4)/Headphone Jack           Wi-Fi/Bluetooth
# 23  HDMI/USB-C (Thunderbolt 4)/Headphone Jack           Wi-Fi/Bluetooth
# 24  HDMI/USB-C (Thunderbolt 4)/Headphone Jack           Wi-Fi/Bluetooth
# 25                                  16 GB RAM    1 TB PCIe NVMe M.2 SSD
# 26                                  16 GB RAM    1 TB PCIe NVMe M.2 SSD
# 27                                  16 GB RAM                256 GB SSD
# 28                            Wi-Fi/Bluetooth                 16 GB RAM
# 29                            Wi-Fi/Bluetooth                 16 GB RAM
# 30                            Wi-Fi/Bluetooth                 16 GB RAM
# 31                                   8 GB RAM                256 GB SSD
# 32                                   8 GB RAM                256 GB SSD
# 33                            Wi-Fi/Bluetooth                 16 GB RAM
# 34                                  16 GB RAM    1 TB PCIe NVMe M.2 SSD
# 35                                   4 GB RAM                128 GB SSD
# 36                                   4 GB RAM                  1 TB HDD
# 37                                   8 GB RAM  256 GB PCIe NVMe M.2 SSD
# 38                                   8 GB RAM  512 GB PCIe NVMe M.2 SSD
# 39                            Wi-Fi/Bluetooth                 16 GB RAM
# 40  HDMI/USB-C (Thunderbolt 4)/Headphone Jack           Wi-Fi/Bluetooth
# 41  HDMI/USB-C (Thunderbolt 4)/Headphone Jack           Wi-Fi/Bluetooth
# 42  HDMI/USB-C (Thunderbolt 4)/Headphone Jack           Wi-Fi/Bluetooth
# 43  HDMI/USB-C (Thunderbolt 4)/Headphone Jack           Wi-Fi/Bluetooth
# 44  HDMI/USB-C (Thunderbolt 4)/Headphone Jack           Wi-Fi/Bluetooth
# 45                                  16 GB RAM    1 TB PCIe NVMe M.2 SSD
# 46                                  16 GB RAM    1 TB PCIe NVMe M.2 SSD
# 47                                  16 GB RAM                256 GB SSD
# 48                            Wi-Fi/Bluetooth                 16 GB RAM
# 49                            Wi-Fi/Bluetooth                 16 GB RAM
# 50                            Wi-Fi/Bluetooth                 16 GB RAM
# 51                                   8 GB RAM                256 GB SSD
# 52                                   8 GB RAM                256 GB SSD
# 53                            Wi-Fi/Bluetooth                 16 GB RAM
#
#                          Gpu           OpSys               Weight  Price
# 0            Wi-Fi/Bluetooth  MacOS Monterey  1.60 kg ( 3.53 lb )   9499
# 1            Wi-Fi/Bluetooth  MacOS Monterey  2.10 kg ( 4.63 lb )  11799
# 2            Wi-Fi/Bluetooth  MacOS Monterey  2.10 kg ( 4.63 lb )  11799
# 3            Wi-Fi/Bluetooth  MacOS Monterey  2.10 kg ( 4.63 lb )  12749
# 4            Wi-Fi/Bluetooth  MacOS Monterey  1.60 kg ( 3.53 lb )  11799
# 5     1 TB PCIe NVMe M.2 SSD      Windows 10        height/length   4899
# 6     1 TB PCIe NVMe M.2 SSD      Windows 10                 None   6839
# 7                 256 GB SSD      Windows 10                 None   5999
# 8                  16 GB RAM  macOS Catalina  2.00 kg ( 4.41 lb )  10499
# 9                  16 GB RAM  macOS Catalina  1.40 kg ( 3.09 lb )   8999
# 10                 16 GB RAM  macOS Catalina  1.40 kg ( 3.09 lb )   9999
# 11                256 GB SSD      Windows 10                depth   2599
# 12                256 GB SSD      Windows 10                depth   2299
# 13                 16 GB RAM  macOS Catalina  1.40 kg ( 3.09 lb )   8299
# 14    1 TB PCIe NVMe M.2 SSD      Windows 10                width   8799
# 15                128 GB SSD      Windows 10  1.30 kg ( 2.87 lb )   1399
# 16                  1 TB HDD      Windows 10                depth   2299
# 17  256 GB PCIe NVMe M.2 SSD      Windows 10                depth   3599
# 18  512 GB PCIe NVMe M.2 SSD      Windows 10                depth   4499
# 19                 16 GB RAM      Windows 10                depth   6199
# 20           Wi-Fi/Bluetooth  MacOS Monterey  1.60 kg ( 3.53 lb )   9499
# 21           Wi-Fi/Bluetooth  MacOS Monterey  2.10 kg ( 4.63 lb )  11799
# 22           Wi-Fi/Bluetooth  MacOS Monterey  2.10 kg ( 4.63 lb )  11799
# 23           Wi-Fi/Bluetooth  MacOS Monterey  2.10 kg ( 4.63 lb )  12749
# 24           Wi-Fi/Bluetooth  MacOS Monterey  1.60 kg ( 3.53 lb )  11799
# 25    1 TB PCIe NVMe M.2 SSD      Windows 10        height/length   4899
# 26    1 TB PCIe NVMe M.2 SSD      Windows 10                 None   6839
# 27                256 GB SSD      Windows 10                 None   5999
# 28                 16 GB RAM  macOS Catalina  2.00 kg ( 4.41 lb )  10499
# 29                 16 GB RAM  macOS Catalina  1.40 kg ( 3.09 lb )   8999
# 30                 16 GB RAM  macOS Catalina  1.40 kg ( 3.09 lb )   9999
# 31                256 GB SSD      Windows 10                depth   2599
# 32                256 GB SSD      Windows 10                depth   2299
# 33                 16 GB RAM  macOS Catalina  1.40 kg ( 3.09 lb )   8299
# 34    1 TB PCIe NVMe M.2 SSD      Windows 10                width   8799
# 35                128 GB SSD      Windows 10  1.30 kg ( 2.87 lb )   1399
# 36                  1 TB HDD      Windows 10                depth   2299
# 37  256 GB PCIe NVMe M.2 SSD      Windows 10                depth   3599
# 38  512 GB PCIe NVMe M.2 SSD      Windows 10                depth   4499
# 39                 16 GB RAM      Windows 10                depth   6199
# 40           Wi-Fi/Bluetooth  MacOS Monterey  1.60 kg ( 3.53 lb )   9499
# 41           Wi-Fi/Bluetooth  MacOS Monterey  2.10 kg ( 4.63 lb )  11799
# 42           Wi-Fi/Bluetooth  MacOS Monterey  2.10 kg ( 4.63 lb )  11799
# 43           Wi-Fi/Bluetooth  MacOS Monterey  2.10 kg ( 4.63 lb )  12749
# 44           Wi-Fi/Bluetooth  MacOS Monterey  1.60 kg ( 3.53 lb )  11799
# 45    1 TB PCIe NVMe M.2 SSD      Windows 10        height/length   4899
# 46    1 TB PCIe NVMe M.2 SSD      Windows 10                 None   6839
# 47                256 GB SSD      Windows 10                 None   5999
# 48                 16 GB RAM  macOS Catalina  2.00 kg ( 4.41 lb )  10499
# 49                 16 GB RAM  macOS Catalina  1.40 kg ( 3.09 lb )   8999
# 50                 16 GB RAM  macOS Catalina  1.40 kg ( 3.09 lb )   9999
# 51                256 GB SSD      Windows 10                depth   2599
# 52                256 GB SSD      Windows 10                depth   2299
# 53                 16 GB RAM  macOS Catalina  1.40 kg ( 3.09 lb )   8299

# %%
df=df.to_csv('Data.csv')
