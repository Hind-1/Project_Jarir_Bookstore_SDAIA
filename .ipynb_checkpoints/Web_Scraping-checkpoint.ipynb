# %% [markdown]
# ## Web Scraping

# %%
from selenium import webdriver as web
import time, os
# from selenium.webdriver.common.keys import Keys

from bs4 import BeautifulSoup
import requests
#  webdriver is what is driving these actions.
# It's what'is links up with the browser.
# It's what's able to perform the action

# %%
PATH='/Applications/chromedriver'
os.environ["webdriver.chrome.driver"] = PATH
driver=web.Chrome(PATH)

# The web browser i want to use is chrome and the web driver for this browser is locted at PATH.

# %%
driver.get('https://www.jarir.com')

# %% [markdown]
# Now we parse this with `BeautifulSoup` and the bookstore information appears!

# %%
driver.find_element_by_xpath('/html/body/div[3]/div/div[1]/div/div/div[3]/ul/div/div/div[5]/div/li/a/div/img').click()

# %%
#  This line will view the laptops page.

driver.find_element_by_xpath('//*[@id="amshopby-page-container"]/div[7]/ul/li[1]/a/div/img').click()

# %% [markdown]
# Now we want to collect all the link of the product that show in page.

# %%
from selenium.webdriver.common.action_chains import ActionChains

# %%
listOflinks=[]
conditin=True
while conditin:
    productInfolist=driver.find_elements_by_class_name('item')
    for p in productInfolist:
        p1=p.find_element_by_tag_name('a')
        p2=p1.get_property('href')
        listOflinks.append(p2)
    try:
        button = driver.find_element_by_xpath("/html/body/div[3]/div/div[1]/div[2]/div[2]/div[2]/div[4]/div[4]")
        ActionChains(driver).move_to_element(button).click(button).perform()    
    except:
        conditin=False
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-94-77da9e9cb8c1> in <module>
#       2 conditin=True
#       3 while conditin:
# ----> 4     productInfolist=driver.find_elements_by_class_name('item')
#       5     for p in productInfolist:
#       6         p1=p.find_element_by_tag_name('a')
#
# /opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_elements_by_class_name(self, name)
#     578             elements = driver.find_elements_by_class_name('foo')
#     579         """
# --> 580         return self.find_elements(by=By.CLASS_NAME, value=name)
#     581
#     582     def find_element_by_css_selector(self, css_selector):
#
# /opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_elements(self, by, value)
#    1003         # Return empty list if driver returns null
#    1004         # See https://github.com/SeleniumHQ/selenium/issues/4555
# -> 1005         return self.execute(Command.FIND_ELEMENTS, {
#    1006             'using': by,
#    1007             'value': value})['value'] or []
#
# /opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# /opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=94.0.4606.71)

# %%
#  That show the number of all product
len(listOflinks)

# %%
tempj={ 'Company':[],
       'Product':[],
       'TypeName':[],
       'Inches':[],
       'ScreenResolution':[],
       'Gpu':[],
       'Ram':[],
       'Memory':[],
       'OpSys':[],
       'Weight':[],
       'Price':[],
}
for link in range(len(listOflinks)):
    driver.get(listOflinks[link])
    english_page = driver.find_element_by_xpath('//*[@id="page-header"]/div[1]/div/ul/li[8]/a/div[2]')
    english_page.click()
    Company=driver.find_element_by_xpath('//*[@id="card-specifications"]/div/table/tbody/tr[9]/td').get_attribute('textContent').strip()
    Product=driver.find_element_by_xpath('//*[@id="card-specifications"]/div/table/tbody/tr[9]/td').get_attribute('textContent').strip()
    TypeName=driver.find_element_by_xpath('//*[@id="card-specifications"]/div/table/tbody/tr[8]/td').get_attribute('textContent').strip()
    Inches=driver.find_element_by_xpath('//*[@id="card-specifications"]/div/table/tbody/tr[6]/td').get_attribute('textContent').strip().replace("\"", "")
    ScreenResolution=driver.find_element_by_xpath('//*[@id="card-specifications"]/div/table/tbody/tr[19]/td').get_attribute('textContent').strip()
    Gpu=driver.find_element_by_xpath('//*[@id="card-specifications"]/div/table/tbody/tr[4]/td').get_attribute('textContent').strip()
    Ram=driver.find_element_by_xpath('//*[@id="card-specifications"]/div/table/tbody/tr[15]/td').get_attribute('textContent').strip()
    Memory=driver.find_element_by_xpath('//*[@id="card-specifications"]/div/table/tbody/tr[14]/td').get_attribute('textContent').strip()
    OpSys=driver.find_element_by_xpath('//*[@id="card-specifications"]/div/table/tbody/tr[7]/td').get_attribute('textContent').strip()
    Price=driver.find_element_by_class_name('price').get_attribute('textContent').strip().replace("SR", "")
    Company1=Company[:7]
    Company2=Company[:6]
    Company3=Company[:11]
    Company4=Company[:8]
    if Company1=='(Apple)'or Company2=='(Asus)':
        Weight=driver.find_element_by_xpath('//*[@id="card-specifications"]/div/table/tbody/tr[24]/td').get_attribute('textContent').strip()
    else:
        Weight=driver.find_element_by_xpath('//*[@id="card-specifications"]/div/table/tbody/tr[27]/td').get_attribute('textContent').strip()

                
    tempj['Company'].append(Company)
    tempj['Product'].append(Product)
    tempj['TypeName'].append(TypeName)
    tempj['Inches'].append(Inches)
    tempj['ScreenResolution'].append(ScreenResolution)
    tempj['Gpu'].append(Gpu)
    tempj['Ram'].append(Ram)
    tempj['Memory'].append(Memory)
    tempj['OpSys'].append(OpSys)
    tempj['Weight'].append(Weight)
    tempj['Price'].append(Price)
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# <ipython-input-63-5ece05a70796> in <module>
#      14     driver.get(listOflinks[link])
#      15     english_page = driver.find_element_by_xpath('//*[@id="page-header"]/div[1]/div/ul/li[8]/a/div[2]')
# ---> 16     english_page.click()
#      17     Company=driver.find_element_by_xpath('//*[@id="card-specifications"]/div/table/tbody/tr[9]/td').get_attribute('textContent').strip()
#      18     Product=driver.find_element_by_xpath('//*[@id="card-specifications"]/div/table/tbody/tr[9]/td').get_attribute('textContent').strip()
#
# /opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# /opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# /opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# /opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# ElementNotInteractableException: Message: element not interactable
#   (Session info: chrome=94.0.4606.71)

# %%
Price
# Out:
# '2599ر.س.\u200f'

# %%
import pandas as pd

# %%
df=pd.DataFrame(tempj)
df
# Out:
#                        Company                     Product TypeName  Inches  \
# 0            (Huawei) MateBook           (Huawei) MateBook   Laptop    13.9
# 1   (Microsoft) Surface Laptop  (Microsoft) Surface Laptop   Laptop    13.5
# 2                (Lenovo) YOGA               (Lenovo) YOGA   Laptop    14.0
# 3   (Microsoft) Surface Laptop  (Microsoft) Surface Laptop   Laptop    15.0
# 4           (Asus) ZenBook Pro          (Asus) ZenBook Pro   Laptop    15.6
# 5               (Asus) ZenBook              (Asus) ZenBook   Laptop    13.3
# 6               (Asus) ZenBook              (Asus) ZenBook   Laptop    14.0
# 7          (Apple) MacBook Pro         (Apple) MacBook Pro   Laptop    16.0
# 8          (Apple) MacBook Pro         (Apple) MacBook Pro   Laptop    13.3
# 9          (Apple) MacBook Pro         (Apple) MacBook Pro   Laptop    13.3
# 10         (Apple) MacBook Pro         (Apple) MacBook Pro   Laptop    16.0
# 11           (Huawei) MateBook           (Huawei) MateBook   Laptop    15.6
# 12           (Huawei) MateBook           (Huawei) MateBook   Laptop    15.6
# 13         (Apple) MacBook Pro         (Apple) MacBook Pro   Laptop    13.3
# 14           (Huawei) MateBook           (Huawei) MateBook   Laptop    14.0
# 15           (Huawei) MateBook           (Huawei) MateBook   Laptop    13.0
# 16                    (Asus) X                    (Asus) X   Laptop    15.6
# 17             (Dell) Inspiron             (Dell) Inspiron   Laptop    13.3
# 18                  (Dell) XPS                  (Dell) XPS   Laptop    13.4
# 19                  (Dell) XPS                  (Dell) XPS   Laptop    13.3
#
#                       ScreenResolution                             Gpu  \
# 0                          3000 X 2000     NVIDIA GeForce MX250 (2 GB)
# 1                    2256 X 1504 (QHD)        Intel Iris Plus Graphics
# 2                       HD 720p Webcam             Intel Iris Graphics
# 3                          2496 x 1664               AMD Radeon Vega 9
# 4                    3840 X 2160 (UHD)  NVIDIA GeForce RTX 3070 (8 GB)
# 5                            HD Webcam          Intel Iris Xe Graphics
# 6                  1920 X 1080 (WUXGA)     NVIDIA GeForce MX450 (2 GB)
# 7       Dolby Atmos, Three Microphones     AMD Radeon Pro 5300M (4 GB)
# 8                Built-in Mic/Speakers    Intel Iris Plus Graphics 645
# 9                Built-in Mic/Speakers    Intel Iris Plus Graphics 645
# 10      Dolby Atmos, Three Microphones     AMD Radeon Pro 5500M (4 GB)
# 11                    HD (1 MP) Webcam              Intel UHD Graphics
# 12                    HD (1 MP) Webcam              Intel UHD Graphics
# 13               Built-in Mic/Speakers    Intel Iris Plus Graphics 645
# 14                         2160 x 1440          Intel Iris Xe Graphics
# 15                      HD 720p Webcam          Intel Iris Xe Graphics
# 16  Built-in Speakers/Mic, SonicMaster              Intel UHD Graphics
# 17                       0.9 MP Webcam          Intel Iris Xe Graphics
# 18                   3840 X 2160 (UHD)          Intel Iris Xe Graphics
# 19                 Waves MaxxAudio Pro          Intel Iris Xe Graphics
#
#                 Ram                    Memory           OpSys  \
# 0         16 GB RAM    1 TB PCIe NVMe M.2 SSD      Windows 10
# 1         16 GB RAM                256 GB SSD      Windows 10
# 2         16 GB RAM    1 TB PCIe NVMe M.2 SSD      Windows 10
# 3         16 GB RAM                256 GB SSD      Windows 10
# 4         32 GB RAM    1 TB PCIe NVMe M.2 SSD      Windows 10
# 5         16 GB RAM    1 TB PCIe NVMe M.2 SSD      Windows 10
# 6         16 GB RAM    1 TB PCIe NVMe M.2 SSD      Windows 10
# 7   Wi-Fi/Bluetooth                 16 GB RAM  macOS Catalina
# 8   Wi-Fi/Bluetooth                 16 GB RAM  macOS Catalina
# 9   Wi-Fi/Bluetooth                 16 GB RAM  macOS Catalina
# 10  Wi-Fi/Bluetooth                 16 GB RAM  macOS Catalina
# 11         8 GB RAM                256 GB SSD      Windows 10
# 12         8 GB RAM                256 GB SSD      Windows 10
# 13  Wi-Fi/Bluetooth                 16 GB RAM  macOS Catalina
# 14        16 GB RAM                512 GB SSD      Windows 10
# 15         8 GB RAM                512 GB SSD      Windows 10
# 16  Wi-Fi/Bluetooth                  4 GB RAM      Windows 10
# 17         8 GB RAM  256 GB PCIe NVMe M.2 SSD      Windows 10
# 18        16 GB RAM    1 TB PCIe NVMe M.2 SSD      Windows 10
# 19  Wi-Fi/Bluetooth                 16 GB RAM      Windows 10
#
#                    Weight    Price
# 0     1.33 kg ( 2.93 lb )   4899.0
# 1                  2.5300   5299.0
# 2                  2.5000   6839.0
# 3                  2.5300   5999.0
# 4    24.92 cm ( 9.81 in )  15499.0
# 5    20.30 cm ( 7.99 in )   5149.0
# 6   32.40 cm ( 12.76 in )   7699.0
# 7     2.00 kg ( 4.41 lb )  10499.0
# 8     1.40 kg ( 3.09 lb )   9999.0
# 9     1.40 kg ( 3.09 lb )   8999.0
# 10    2.00 kg ( 4.41 lb )  12699.0
# 11                 2.3600   2599.0
# 12                 2.3600   2299.0
# 13    1.40 kg ( 3.09 lb )   8299.0
# 14    1.49 kg ( 3.28 lb )   4999.0
# 15                 1.8000   3999.0
# 16    1.80 kg ( 3.97 lb )   2199.0
# 17                 0.0100   3599.0
# 18   10.92 cm ( 4.30 in )   8799.0
# 19                 2.6500   6199.0

# %%
len(tempj['Company'])

# %%
df.shape
